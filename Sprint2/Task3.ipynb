// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания : 2

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Описание задачи:
// Создать базовый класс <em>Student</em> в C#, который будет представлять информацию о
// студентах. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.<br>
//
// <b>Требования к базовому классу Student:</b>
// * Атрибуты: Имя (<em>Name</em>), Возраст (<em>Age</em>), Курс (<em>Course</em>).
// * Методы:
//     * <em>GetInfo()</em>: метод для получения информации о студенте в виде строки.
//     * <em>Study()</em>: метод для вывода сообщения о том, что студент учится.
//     * <em>TakeExam()</em>: метод для вывода сообщения о сдаче экзамена.<br>
//
// <b>Требования к производным классам:</b>
// 1. Студент бакалавриата (<em>BachelorStudent</em>): Должен содержать дополнительные
// атрибуты, такие как Специальность (<em>Specialty</em>). Метод <em>Study()</em> должен быть
// переопределен для добавления информации о специальности при изучении
// предмета.
// 2. Студент магистратуры (<em>MasterStudent</em>): Должен содержать дополнительные
// атрибуты, такие как Научный руководитель (<em>ScientificAdvisor</em>).
// Метод <em>TakeExam()</em> должен быть переопределен для добавления
// информации о научном руководителе при сдаче экзамена.
// 3. Аспирант (<em>PhDStudent</em>) (если требуется третий класс): Должен содержать
// дополнительные атрибуты, такие как Тема диссертации (<em>DissertationTopic</em>).
// Метод <em>Study()</em> должен быть переопределен для добавления информации о
// теме диссертации при изучении предмета.
//
//
// #### Дополнительное задание
// Добавьте к существующим классам (базовому и производным 3-4 атрибута и метода) и реализуйте простое, сложное и множественное наследование

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public interface IStudy
{
    void Study();
}

public interface IExam
{
    void TakeExam();
}

public class Student: IStudy, IExam // множественное наследование
{
    public string Name { get; set; }
    public int Age { get; set; }
    public int Course { get; set; }
 
    public Student(string name, int age, int course)
    {
        Name = name;
        Age = age;
        Course = course;
    }

    public virtual string GetInfo()
    {
        return $"Студент: {Name}, {Age} лет, {Course} курс";
    }

    public virtual void Study()
    {
        Console.WriteLine($"{Name} учится в Тюменском индустриальном университете");
    }

    public virtual void TakeExam()
    {
        Console.WriteLine($"{Name} сдает экзамены");
    }
    
    public void Congratulations(Student other)
    {
        other.Age++;
        Console.WriteLine($"{Name} поздравлет {other.Name} с Днем Рождения, ему исполнилось {other.Age}!");
    }
}

public class BachelorStudent : Student
{
    public string Specialty { get; set; }
    public string InternshipCompany { get; set; } // добавленный атрибут (компания стажировки)

    public BachelorStudent(string name, int age, int course, string specialty, string internshipCompany)
        : base(name, age, course)
    {
        Specialty = specialty;
        InternshipCompany = internshipCompany;
    }
    
    public override void Study()
    {
        Console.WriteLine($"Учится в Тюменском индустриальном университете по специальности {Specialty}");
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Специальность: {Specialty}, Компания стажировки: {InternshipCompany}";
    }

    public void ApplyForInternship()
    {
        Console.WriteLine($"{Name} подает заявку на стажировку в компании {InternshipCompany}"); // добавленный метод (подача заявки на стажировку)
    }
}

public class MasterStudent : Student
{
    public string ScientificAdvisor { get; set; }
    public int PublishedPapers { get; set; } // добавленный атрибут (кол-во статей)

    public MasterStudent(string name, int age, int course, string scientificAdvisor, int publishedPapers)
        : base(name, age, course)
    {
        ScientificAdvisor = scientificAdvisor;
        PublishedPapers = publishedPapers;
    }

    public override void TakeExam()
    {
        Console.WriteLine($"{Name} сдает экзамен под руководством {ScientificAdvisor}");
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Научный руководитель: {ScientificAdvisor}, Опубликованные статьи: {PublishedPapers}";
    }
}

public class PhDStudent : Student
{
    public string DissertationTopic { get; set; }

    public PhDStudent(string name, int age, int course, string dissertationTopic)
        : base(name, age, course)
    {
        DissertationTopic = dissertationTopic;
    }

    public override void Study()
    {
        Console.WriteLine($"{Name} изучает тему диссертации: {DissertationTopic}");
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Тема диссертации: {DissertationTopic}";
    }
}

public class Youngster : BachelorStudent // сложное наследование
{
    public Youngster(string name, int age, int course, string specialty, string internshipCompany) :base (name, age,  course,  specialty, internshipCompany) {}

    public void Work()
    {
        Console.WriteLine($"Подрабатывает в компании {InternshipCompany}");
    }

    public void Sleep()
    {
        Console.WriteLine("Отсыпается после учебы и работы");
    }
}


BachelorStudent student1 = new BachelorStudent("Екатерина", 18, 2, "Искусственный интеллект и программирование", "TechCorp");
MasterStudent student2 = new MasterStudent("Анна", 22, 1, "Петрова И.И.", 4);
PhDStudent student3 = new PhDStudent("Владислав", 28, 3, "Искусственный интеллект");

Youngster man = new Youngster("Ваня", 20, 3, "Нефтедобычы", "Газпром");

Console.WriteLine(student1.GetInfo());
student1.Study();
student1.TakeExam();


Console.WriteLine();

Console.WriteLine(student2.GetInfo());
student2.Study();
student2.TakeExam();

Console.WriteLine();

Console.WriteLine(student3.GetInfo());
student3.Study();
student3.TakeExam();

Console.WriteLine();

Console.WriteLine(man.GetInfo());
man.Work();
man.Sleep();
// Out:
// Студент: Екатерина, 18 лет, 2 курс, Специальность: Искусственный интеллект и программирование, Компания стажировки: TechCorp
// Учится в Тюменском индустриальном университете по специальности Искусственный интеллект и программирование
// Екатерина сдает экзамены
//
// Студент: Анна, 22 лет, 1 курс, Научный руководитель: Петрова И.И., Опубликованные статьи: 4
// Анна учится в Тюменском индустриальном университете
// Анна сдает экзамен под руководством Петрова И.И.
//
// Студент: Владислав, 28 лет, 3 курс, Тема диссертации: Искусственный интеллект
// Владислав изучает тему диссертации: Искусственный интеллект
// Владислав сдает экзамены
//
// Студент: Ваня, 20 лет, 3 курс, Специальность: Нефтедобычы, Компания стажировки: Газпром
// Подрабатывает в компании Газпром
// Отсыпается после учебы и работы
